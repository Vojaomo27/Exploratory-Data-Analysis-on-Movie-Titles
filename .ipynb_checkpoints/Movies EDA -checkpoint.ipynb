# %%
import pandas as pd

# %%
movies = pd.read_csv('titles.csv')

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=5850, step=1)

# %%
movies.shape
# Out:
# (5850, 15)

# %%
movies.size
# Out:
# 87750

# %%
movies.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
movies.ndim
# Out:
# 2

# %%
movies.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes
# count   5850.000000  5850.000000  2106.000000  5368.000000  5.352000e+03  \
# mean    2016.417094    76.888889     2.162868     6.510861  2.343938e+04
# std        6.937726    39.002509     2.689041     1.163826  9.582047e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.000000     2.000000     7.300000  9.494000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5759.000000  5539.000000
# mean         22.637925     6.829175
# std          81.680263     1.170391
# min           0.009442     0.500000
# 25%           2.728500     6.100000
# 50%           6.821000     6.900000
# 75%          16.590000     7.537500
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %%
movies.sample()
# Out:
#            id title   type                                        description
# 704  tm170758   Hop  MOVIE  E.B., the Easter Bunny's teenage son, heads to...  \
#
#      release_year age_certification  runtime
# 704          2011                PG      101  \
#
#                                            genres production_countries
# 704  ['animation', 'comedy', 'family', 'fantasy']               ['US']  \
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 704      NaN  tt1411704         5.4     34363.0           19.141         5.7

# %%
movies.head()
# Out:
#          id                                title   type
# 0  ts300399  Five Came Back: The Reference Films   SHOW  \
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year
# 0  This collection includes 12 World War II-era p...          1945  \
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres
# 0             TV-MA       51                            ['documentation']  \
# ...

# %%
movies.tail()
# Out:
#              id                                      title   type
# 5845  tm1014599                                  Fine Wine  MOVIE  \
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year
# 5845  A beautiful love story that can happen between...          2021  \
# 5846  A heart warming film that explores the concept...          2021
# 5847  A controversial TV host and comedian who has b...          2021
# 5848  Jamie Foxx, David Alan Grier and more from the...          2021
# 5849  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                             genres
# 5845               NaN      100               ['romance', 'drama']  \
# ...

# %%
movies.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
movies.nunique()
# Out:
# id                      5850
# title                   5798
# type                       2
# description             5829
# release_year              63
# age_certification         11
# runtime                  202
# genres                  1726
# production_countries     452
# seasons                   26
# imdb_id                 5447
# imdb_score                80
# imdb_votes              3880
# tmdb_popularity         4889
# tmdb_score               394
# dtype: int64

# %%
movies.memory_usage()
# Out:
# Index                     128
# id                      46800
# title                   46800
# type                    46800
# description             46800
# release_year            46800
# age_certification       46800
# runtime                 46800
# genres                  46800
# production_countries    46800
# seasons                 46800
# imdb_id                 46800
# imdb_score              46800
# imdb_votes              46800
# tmdb_popularity         46800
# tmdb_score              46800
# dtype: int64

# %%
movies.isna().head()
# Out:
#       id  title   type  description  release_year  age_certification  runtime
# 0  False  False  False        False         False              False    False  \
# 1  False  False  False        False         False              False    False
# 2  False  False  False        False         False              False    False
# 3  False  False  False        False         False              False    False
# 4  False  False  False        False         False               True    False
#
#    genres  production_countries  seasons  imdb_id  imdb_score  imdb_votes
# 0   False                 False    False     True        True        True  \
# 1   False                 False     True    False       False       False
# 2   False                 False     True    False       False       False
# 3   False                 False     True    False       False       False
# 4   False                 False     True    False       False       False
#
#    tmdb_popularity  tmdb_score
# ...

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5845    False
# 5846    False
# 5847    False
# 5848    False
# 5849    False
# Length: 5850, dtype: bool

# %%
movies['title'].value_counts()
# Out:
# title
# The Gift                                     3
# Connected                                    3
# Fearless                                     2
# A Nightmare on Elm Street                    2
# A Lion in the House                          2
#                                             ..
# Errementari: The Blacksmith and the Devil    1
# The Hollow                                   1
# The Bar                                      1
# Valor                                        1
# Mighty Little Bheem: Kite Festival           1
# Name: count, Length: 5798, dtype: int64

# %%
movies.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
movies
# Out:
#              id                                      title   type
# 0      ts300399        Five Came Back: The Reference Films   SHOW  \
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year
# 0     This collection includes 12 World War II-era p...          1945  \
# ...

# %%
movies.shape
# Out:
# (5850, 15)

# %%
movies.dropna()
# Out:
#             id                               title  type
# 5      ts22164        Monty Python's Flying Circus  SHOW  \
# 26     ts45948    Monty Python's Fliegender Zirkus  SHOW
# 35     ts20681                            Seinfeld  SHOW
# 44     ts22082                        Knight Rider  SHOW
# 45     ts21715                    Thomas & Friends  SHOW
# ...        ...                                 ...   ...
# 5784  ts285471                   The Wedding Coach  SHOW
# 5785  ts325991                  Only Jokes Allowed  SHOW
# 5801  ts270616         We Are: The Brooklyn Saints  SHOW
# 5819  ts287729  Alma Matters: Inside the IIT Dream  SHOW
# 5831  ts273317                       Pitta Kathalu  SHOW
#
#                                             description  release_year
# 5     A British sketch comedy series with the shows ...          1969  \
# 26    Monty Python's Fliegender Zirkus consisted of ...          1972
# ...

# %%
movies.dropna(inplace = True)

# %%
movies.shape
# Out:
# (1667, 15)

# %%
movies.to_csv(r"C:\Users\USER\Desktop\EDA assignment\movies.csv")
